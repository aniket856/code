# %%
csv = comma seprated value

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Admin/Downloads/pima-indians-diabetes.csv")
data
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
data = pd.read_csv("C:/Users/Admin/Downloads/pima-indians-diabetes.csv",names['head1','head2','head1','head2','head1','head2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12948\3569392290.py in <module>
# ----> 1 data = pd.read_csv("C:/Users/Admin/Downloads/pima-indians-diabetes.csv",names['head1','head2','head1','head2','head1','head2'])
#
# NameError: name 'names' is not defined

# %%
#import file online
data3 = pd.read_excel('https://www.eia.gov/dnav/pet/hist_xls/RBRTed.xls')
data3
# Out:
#     Unnamed: 0                                        Unnamed: 1  \
# 0          NaN                                 Workbook Contents
# 1          NaN  Europe Brent Spot Price FOB (Dollars per Barrel)
# 2          NaN                                               NaN
# 3          NaN    Click worksheet name or tab at bottom for data
# 4          NaN                                    Worksheet Name
# 5          NaN                                            Data 1
# 6          NaN                                               NaN
# 7          NaN                                     Release Date:
# 8          NaN                                Next Release Date:
# 9          NaN                                  Excel File Name:
# 10         NaN                          Available from Web Page:
# 11         NaN                                           Source:
# 12         NaN                                For Help, Contact:
# ...

# %%
# if get error while accessing online file
# !pip install xlrd==1.2.0 #install  this
pip install --upgrade xlrd #or use this

# %%
data4 = pd.read_excel('https://www.eia.gov/dnav/pet/hist_xls/RBRTed.xls',skiprows = 6)
data4
# Out:
#    Unnamed: 0                    Data 1  \
# 0         NaN                       NaN
# 1         NaN             Release Date:
# 2         NaN        Next Release Date:
# 3         NaN          Excel File Name:
# 4         NaN  Available from Web Page:
# 5         NaN                   Source:
# 6         NaN        For Help, Contact:
# 7         NaN                       NaN
#
#     Europe Brent Spot Price FOB (Dollars per Barrel)   1  Daily  \
# 0                                                NaN NaN    NaN
# 1                                           6/1/2023 NaN    NaN
# 2                                           6/7/2023 NaN    NaN
# 3                                         rbrted.xls NaN    NaN
# 4  https://www.eia.gov/dnav/pet/hist/LeafHandler.... NaN    NaN
# 5                                                NaN NaN    NaN
# 6                                infoctr@eia.doe.gov NaN    NaN
# 7                                     (202) 586-8800 NaN    NaN
#
# ...

# %%
data3 #first step : to see the file and import it
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 762  10  101  76  48  180  32.9  0.171  63  0
# 763   2  122  70  27    0  36.8  0.340  27  0
# 764   5  121  72  23  112  26.2  0.245  30  0
# 765   1  126  60   0    0  30.1  0.349  47  1
# 766   1   93  70  31    0  30.4  0.315  23  0
#
# [767 rows x 9 columns]

# %%
data.shape #second step
# Out:
# (767, 9)

# %%
data.dtypes # third : to check type of datad
# Out:
# 6          int64
# 148        int64
# 72         int64
# 35         int64
# 0          int64
# 33.6     float64
# 0.627    float64
# 50         int64
# 1          int64
# dtype: object

# %%
data.describe() # for statics (will give mean, max and all)
# Out:
#                 6         148          72          35           0        33.6  \
# count  767.000000  767.000000  767.000000  767.000000  767.000000  767.000000
# mean     3.842243  120.859192   69.101695   20.517601   79.903520   31.990482
# std      3.370877   31.978468   19.368155   15.954059  115.283105    7.889091
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   32.000000   32.000000
# 75%      6.000000  140.000000   80.000000   32.000000  127.500000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#             0.627          50           1
# count  767.000000  767.000000  767.000000
# mean     0.471674   33.219035    0.348110
# std      0.331497   11.752296    0.476682
# min      0.078000   21.000000    0.000000
# 25%      0.243500   24.000000    0.000000
# ...

# %%
data.describe().T
# Out:
#        count        mean         std     min      25%      50%      75%  \
# 6      767.0    3.842243    3.370877   0.000   1.0000    3.000    6.000
# 148    767.0  120.859192   31.978468   0.000  99.0000  117.000  140.000
# 72     767.0   69.101695   19.368155   0.000  62.0000   72.000   80.000
# 35     767.0   20.517601   15.954059   0.000   0.0000   23.000   32.000
# 0      767.0   79.903520  115.283105   0.000   0.0000   32.000  127.500
# 33.6   767.0   31.990482    7.889091   0.000  27.3000   32.000   36.600
# 0.627  767.0    0.471674    0.331497   0.078   0.2435    0.371    0.625
# 50     767.0   33.219035   11.752296  21.000  24.0000   29.000   41.000
# 1      767.0    0.348110    0.476682   0.000   0.0000    0.000    1.000
#
#           max
# 6       17.00
# 148    199.00
# 72     122.00
# 35      99.00
# 0      846.00
# 33.6    67.10
# 0.627    2.42
# 50      81.00
# 1        1.00

# %%
data['1'].value_counts() #to check balance or imbalance
# Out:
# 0    500
# 1    267
# Name: 1, dtype: int64

# %%
data.corr() #its always in the form of (-1, 0, 1)
# Out:
#               6       148        72        35         0      33.6     0.627  \
# 6      1.000000  0.128846  0.141197 -0.082495 -0.072999  0.017518 -0.033927
# 148    0.128846  1.000000  0.152498  0.056381  0.332383  0.220955  0.136903
# 72     0.141197  0.152498  1.000000  0.207308  0.089098  0.281777  0.041180
# 35    -0.082495  0.056381  0.207308  1.000000  0.437974  0.392553  0.183498
# 0     -0.072999  0.332383  0.089098  0.437974  1.000000  0.198111  0.185579
# 33.6   0.017518  0.220955  0.281777  0.392553  0.198111  1.000000  0.140546
# 0.627 -0.033927  0.136903  0.041180  0.183498  0.185579  0.140546  1.000000
# 50     0.544018  0.262408  0.239571 -0.115873 -0.040942  0.035911  0.032738
# 1      0.221087  0.465856  0.064882  0.073265  0.131984  0.292695  0.173245
#
#              50         1
# 6      0.544018  0.221087
# 148    0.262408  0.465856
# 72     0.239571  0.064882
# 35    -0.115873  0.073265
# 0     -0.040942  0.131984
# 33.6   0.035911  0.292695
# ...

# %%
data.skew()
# Out:
# 6        0.903976
# 148      0.176412
# 72      -1.841911
# 35       0.112058
# 0        2.270630
# 33.6    -0.427950
# 0.627    1.921190
# 50       1.135165
# 1        0.638949
# dtype: float64

# %%
data.isnull().sum() #check null values
# Out:
# 6        0
# 148      0
# 72       0
# 35       0
# 0        0
# 33.6     0
# 0.627    0
# 50       0
# 1        0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# better to use univariate ploting rather than biovariate
in univariate : go for histrogram, density plot, box plot

# %%
data.hist(figsize=(10,10)) #isme skew ka bhi andaja ho jata hai
plt.show()

# %%
data.plot(kind='density' , subplots=True , figsize=(10,10), layout=(3,3), sharex=False)
plt.show()
