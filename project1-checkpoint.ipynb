# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data = pd.read_csv('auto-mpg.csv')

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#origin 1.America 2. Europe 3. Japaneese
data.shape
# Out:
# (398, 9)

# %%
data['origin'] = data['origin'].replace({1:'America', 2:'Europe',3:'Japaneese'})
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year   origin                   car name
# 0            70  America  chevrolet chevelle malibu
# ...

# %%
data = data.drop('car name', axis=1) # axix = 1 used for col, while axis = 0 used for row
# del data['carname']

# %%
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year   origin
# 0            70  America
# 1            70  America
# 2            70  America
# 3            70  America
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year   origin
# 0            70  America
# 1            70  America
# 2            70  America
# 3            70  America
# ...

# %%
df.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model year  origin
# 0         False   False
# 1         False   False
# 2         False   False
# 3         False   False
# ...

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
df.dtypes #horsepower is object, thus, need to fix it
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %%
HPdigit = pd.DataFrame(data.horsepower.str.isdigit())

# %%
HPdigit
# Out:
#      horsepower
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ..          ...
# 393        True
# 394        True
# 395        True
# 396        True
# 397        True
#
# [398 rows x 1 columns]

# %%
HPdigit.dtypes
# Out:
# horsepower    bool
# dtype: object

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %%
data[HPdigit['horsepower']==False]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model year   origin
# 32           71  America
# 126          74  America
# 330          80   Europe
# 336          80  America
# 354          81   Europe
# 374          82  America

# %%
data = data.replace('?',np.nan)
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year   origin
# 0            70  America
# 1            70  America
# 2            70  America
# 3            70  America
# ...

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %%
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
data.median()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2028\4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# horsepower        93.5
# weight          2803.5
# acceleration      15.5
# model year        76.0
# dtype: float64

# %%
data['horsepower'] = data['horsepower'].fillna(data['horsepower'].median())
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year   origin
# 0            70  America
# 1            70  America
# 2            70  America
# 3            70  America
# ...

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %%
data.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# dtype: int64

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %%
data['horsepower'] = data['horsepower'].astype('float64') #astype :  to convert in in float or int forever change (in file as well) while, int() is temp

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year   origin
# 0            70  America
# 1            70  America
# 2            70  America
# 3            70  America
# ...

# %%
data.dtypes #if u'd'hv convert in int64, it'll be.
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin           object
# dtype: object

# %%
data = pd.get_dummies(data,'origin')
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin_America  origin_Europe  origin_Japaneese
# 0            70               1              0                 0
# ...

# %%
data_attributes =data.iloc[:,0:7]
sns.pairplot(data_attributes,diag_kind='kde')

# %%
data.shape #note : got changed from  8 to 10
# Out:
# (398, 10)

# %%
#y=mx+c -> simple linearRegression (LR)
#y= m1x1+c1+m2x2+....+c -> multiple LR

# %%
y= data['mpg']
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
x = data.drop('mpg', axis=1) #dropped 'mpg'. coz, mpg is y which is output/target (for training we don't need it that's why)
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0            8         307.0       130.0    3504          12.0          70
# 1            8         350.0       165.0    3693          11.5          70
# 2            8         318.0       150.0    3436          11.0          70
# 3            8         304.0       150.0    3433          12.0          70
# 4            8         302.0       140.0    3449          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 393          4         140.0        86.0    2790          15.6          82
# 394          4          97.0        52.0    2130          24.6          82
# 395          4         135.0        84.0    2295          11.6          82
# 396          4         120.0        79.0    2625          18.6          82
# 397          4         119.0        82.0    2720          19.4          82
#
#      origin_America  origin_Europe  origin_Japaneese
# ...

# %%
len(x)
# Out:
# 398

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=30,random_state=1) #test_size 30 mns, it will keep 30% data 
# for testing, on remainig 70% of data will be traied( always keep traing quantity large than testing. so that it will be tested effectively)

# %%
len(x_train)
# Out:
# 368

# %%
len(x_test)
# Out:
# 30

# %%
len(y_train)
# Out:
# 368

# %%
len(y_test)
# Out:
# 30

# %%
ml_reg_model = LinearRegression() #obj created

# %%
ml_reg_model
# Out:
# LinearRegression()

# %%
ml_reg_model.fit(x_train,y_train) #mns 70% of x and 70% of y data will be provied  for testing
# Out:
# LinearRegression()

# %%
ml_reg_model.coef_ #we've got corresponding coef (m value we can say)
# Out:
# array([-0.40421989,  0.02206009, -0.01367244, -0.00687244,  0.09248867,
#         0.7979037 , -1.87407988,  1.09915909,  0.77492079])

# %%
ml_reg_model.intercept_ #value of c (y = mx + c)
# Out:
# -17.90741572898575

# %%
ml_reg_model.predict(x_test)
# Out:
# array([20.91572339, 27.9105151 , 19.87447178, 26.91029577, 23.95976188,
#        15.67826776, 29.62464637, 34.50802545, 16.74796919, 10.72868903,
#        29.98625256, 16.51014614, 22.04202796, 27.49425128, 36.3324899 ,
#        23.84875065, 10.6862454 , 20.11481585,  9.01962611, 33.16486217,
#        26.47426397, 32.09537117, 20.59711003, 25.54122185, 25.75554714,
#        29.87372636, 32.64144779, 32.64931286, 14.85408038, 29.78905522])

# %%
y_test
# Out:
# 174    18.0
# 359    28.1
# 250    19.4
# 274    20.3
# 283    20.2
# 232    16.0
# 117    29.0
# 348    37.7
# 189    15.5
# 106    12.0
# 371    29.0
# 222    17.0
# 261    18.1
# 242    21.5
# 343    39.1
# 179    22.0
# 5      15.0
# 125    20.0
# 90     12.0
# 303    31.8
# 173    24.0
# 233    29.0
# 17     21.0
# 29     27.0
# 315    24.3
# 102    26.0
# 356    32.4
# 246    32.8
# 4      17.0
# 388    26.0
# Name: mpg, dtype: float64

# %%
data.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model year  origin_America  origin_Europe  origin_Japaneese
# 0          70               1              0                 0
# 1          70               1              0                 0
# ...

# %%
# y_pred = ml_reg_model.predict(np.array([6,200,100.0,3000,20,80,0,0,1]).reshape(1,-1))
# y_pred
y_pred  = ml_reg_model.predict(x_test)
y_pred
# Out:
# array([20.91572339, 27.9105151 , 19.87447178, 26.91029577, 23.95976188,
#        15.67826776, 29.62464637, 34.50802545, 16.74796919, 10.72868903,
#        29.98625256, 16.51014614, 22.04202796, 27.49425128, 36.3324899 ,
#        23.84875065, 10.6862454 , 20.11481585,  9.01962611, 33.16486217,
#        26.47426397, 32.09537117, 20.59711003, 25.54122185, 25.75554714,
#        29.87372636, 32.64144779, 32.64931286, 14.85408038, 29.78905522])

# %%
#BiVariate plot

data_attributes = data.iloc[:,0:7]
sns.pairplot(data)

# %%
ml_reg_model.coef_
# Out:
# array([-0.40421989,  0.02206009, -0.01367244, -0.00687244,  0.09248867,
#         0.7979037 , -1.87407988,  1.09915909,  0.77492079])

# %%
ml_reg_model.intercept_
# Out:
# -17.90741572898575

# %%
ml_reg_model.score(x_test,y_test)*100
# Out:
# 84.6149385697558

# %%
print("MAE : ",mean_absolute_error(y_test,y_pred))
print("MSE : ",mean_squared_error(y_test,y_pred))
print("R2 score : ",r2_score(y_test,y_pred))

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)

xGrid, yGrid = np.meshgrid(y, x)

z_final = ml_reg_model.predict(x_test).reshape(-1,1)

z = z_final

final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T

# %%
# fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig = px.area(data, x = data.index, y= data.columns)
# fig.add_trace(go.Surface( x = x, y = y, z =z )) #to add that vertical map
fig.show()

# %%
GOOD JOB!
